# %%
import pandas

# %%
raw_data = pandas.read_csv("reviews.csv")

# %%
df_agg = raw_data.groupby(['listing_id']).head(5)

# %%
df_agg
# Out:
#         listing_id         id        date  reviewer_id reviewer_name  \
# 0              958       5977  2009-07-23        15695      Edmund C
# 1              958       6660  2009-08-03        26145         Simon
# 2              958      11519  2009-09-27        25839         Denis
# 3              958      16282  2009-11-05        33750          Anna
# 4              958      26008  2010-02-13        15416       Venetia
# ...            ...        ...         ...          ...           ...
# 319320    44570944  654405841  2020-08-21     11363570       HyunJoo
# 319321    44570944  655724952  2020-08-23     16066401         Kathi
# 319328    44615683  656164407  2020-08-24     15108350          Sean
# 319329    44966218  658735422  2020-08-30    118772578       Joaquin
# 319330    45067263  660697348  2020-09-05    139787805       Caiseen
#
#                                                  comments
# 0       Our experience was, without a doubt, a five st...
# ...

# %%
raw_data
# Out:
#         listing_id         id        date  reviewer_id reviewer_name  \
# 0              958       5977  2009-07-23        15695      Edmund C
# 1              958       6660  2009-08-03        26145         Simon
# 2              958      11519  2009-09-27        25839         Denis
# 3              958      16282  2009-11-05        33750          Anna
# 4              958      26008  2010-02-13        15416       Venetia
# ...            ...        ...         ...          ...           ...
# 319326    44570944  660691423  2020-09-05    137112284        Selina
# 319327    44570944  661311655  2020-09-06     11535319         Sarah
# 319328    44615683  656164407  2020-08-24     15108350          Sean
# 319329    44966218  658735422  2020-08-30    118772578       Joaquin
# 319330    45067263  660697348  2020-09-05    139787805       Caiseen
#
#                                                  comments
# 0       Our experience was, without a doubt, a five st...
# ...
